# %%
import tkinter as tk
from tkinter import messagebox

def submit():
    weight_ = int(weight_entry.get())
    location_ = int(location_entry.get())
    if location_ > 2 or location_ < 1: 
        messagebox.showerror("Order","Invalid Location Number (Input 1 or 2)",)
    else:
        calculate_price()
        
        
def calculate_price():
    weight_ = int(weight_entry.get())
    location_ = int(location_entry.get())
    root = tk.Tk()
    root.title("Adekunle & Simi's Delivery Service")
    root.geometry('500x250')
    
    if location_entry == 2 and weight_ >=10:
        price = 5000
    

    elif location_entry == 2 and weight_ <10:
        price = 3500
        
        
    elif location_entry == 1 and weight_ >=10:
        price  =10000
        

    else:
        price= 5000
    if location_ == 1:
        label_calc = tk.Label(root, text=f"From the Input Location (Ibeju-Lekki) And Weight ({weight_}KG)\n\nPrice = N{price} ONLY.")
        label_calc.pack()
        return
        
    else:    
        label_calc = tk.Label(root, text=f"From the Input Location (Epe) And Weight ({weight_}KG)\n\nPrice = N{price} ONLY.")
        label_calc.pack()
        return

    
    root.mainloop()
root = tk.Tk()
root.title("Adekunle & Simi's Delivery Service")
root.geometry('500x250')



#location label
location_label = tk.Label(root, text="Please Input your location (Use Number):\n1) Ibeju-Lekki\n2) Epe")
location_label.pack()
location_entry =tk.Entry(root)
location_entry.pack()

weight_label = tk.Label(root, text = "How much weight is the package(In KG)")
weight_label.pack()
weight_entry =tk.Entry(root)
weight_entry.pack()
submit_button = tk.Button(root, text="Submit",command=submit)
submit_button.pack()

root.mainloop()

# %%
# import tkinter as tk
# from tkinter import messagebox

# def admission_stat():
    
#     root = tk.Tk()
#     root.title("Admission  Status")
#     root.geometry("250x100")
    
#     admit_label = tk.Label(root, text=f"Welcome to PAU {name}!!")
#     admit_label.pack()
    
    

    
    
#     root.mainloop()
    
    
# def submit1():
#     departments = int(dept_entry.get())
#     if departments == 1 or departments == 2:
#         fill_stat()
#     else:
#         messagebox.showerror("Input", "Please input a valid Department")
#     root.mainloop()
# def fill_stat():
#     root= tk.Tk()
#     root.title("Pan Atlantic University Admission: Fill Personal Details")
#     root.geometry("750x500")
    
#     info_label = tk.Label(root,text="Please input your details in the following box correctly\n\n")
#     info_label.pack()
#     name_label = tk.Label(root,text="Name:")
#     name_label.pack()
#     name_entry = tk.Entry(root)
#     name_entry.pack()
#     name = name_entry.get()
    
#     jamb_label = tk.Label(root,text="Jamb Score:")
#     jamb_label.pack()
#     jamb_entry = tk.Entry(root)
#     jamb_entry.pack()
#     jamb = jamb_entry.get()
    
#     credits_note_label = tk.Label(root,text="Now input your WASSCE Scores in the following subjects(A, B, C, D, E or F)\n\n")
#     credits_note_label.pack()
#     math_label = tk.Label(root,text="Math:")
#     math_label.pack()
#     math_entry = tk.Entry(root)
#     math_entry.pack()
#     math= math_entry.get()
#     eng_label = tk.Label(root,text="English:")
#     eng_label.pack()
#     eng_entry = tk.Entry(root)
#     eng_entry.get()
#     eng= eng_entry.pack()
#     chem_label = tk.Label(root,text="Chemistry:")
#     chem_label.pack()
#     chem_entry = tk.Entry(root)
#     chem_entry.pack()
#     chem= chem_entry.get()
#     phy_label = tk.Label(root,text="Physics:")
#     phy_label.pack()
#     phy_entry = tk.Entry(root)
#     phy_entry.pack()
#     phy= phy_entry.get()
#     civ_label = tk.Label(root,text="Civics Education")
#     civ_label.pack()
#     civ_entry = tk.Entry(root)
#     civ_entry.pack()
#     civ= civ_entry.get()
    
#     submit_button = tk.Button(root, text="Submit", command=submit)
#     submit_button.pack()

#     root.mainloop()
# def submit():
#     jamb = int(jamb_entry.get())
#     if jamb < 250:
#         messagebox.showerror("Jamb result", "Sorry but your jamb result is not up to expectation")
#     if (math == "D" or math == "E" or math == "F") or (chem == "D" or chem=="E" or chem=="F") or (eng=="F" or eng=="E" or eng=="D") or (civ=="D" or civ=="E" or civ=="F") or (phy =="D" or phy=="E" or phy=="F"):
#         messagebox.showerror("WASSCE Result", "Sorry but your WASSCE result is not up to expectation")
#     else:
#         admission_stat()
        
        
    
#     root.mainloop()    
# root= tk.Tk()
# root.title("Pan Atlantic University Admission")
# root.geometry("500x250")

# #Ask for Department
# dept_label = tk.Label(root,text="Whats your department(Pick with number)\n\n1)Computer Science\n2)Mass Communication")
# dept_label.pack()
# dept_entry = tk.Entry(root)
# dept_entry.pack()

# # department = dept_entry.get()
# # departments = int(department)

# submit1_button = tk.Button(root, text="Submit", command=submit1)
# submit1_button.pack()
    
# root.mainloop()

import tkinter as tk
from tkinter import messagebox

def admission_stat(name):
    messagebox.showinfo("Admission Status", f"Welcome to PAU {name}!!")

def submit1():
    departments = int(dept_entry.get())
    if departments == 1 or departments == 2:
        fill_stat()
    else:
        messagebox.showerror("Input", "Please input a valid Department")

def fill_stat():
    root = tk.Toplevel()
    root.title("Pan Atlantic University Admission: Fill Personal Details")
    root.geometry("750x500")

    def submit():
        name = name_entry.get()
        jamb = int(jamb_entry.get())
        math = math_entry.get()
        eng = eng_entry.get()
        chem = chem_entry.get()
        phy = phy_entry.get()
        civ = civ_entry.get()

        if jamb < 250:
            messagebox.showerror("Jamb result", "Sorry but your jamb result is not up to expectation")
        elif "D" in (math, eng, chem, phy, civ) or "E" in (math, eng, chem, phy, civ) or "F" in (math, eng, chem, phy, civ):
            messagebox.showerror("WASSCE Result", "Sorry but your WASSCE result is not up to expectation")
        else:
            admission_stat(name)
            root.destroy()

    info_label = tk.Label(root, text="Please input your details in the following box correctly\n\n")
    info_label.pack()

    name_label = tk.Label(root, text="Name:")
    name_label.pack()
    name_entry = tk.Entry(root)
    name_entry.pack()

    jamb_label = tk.Label(root, text="Jamb Score:")
    jamb_label.pack()
    jamb_entry = tk.Entry(root)
    jamb_entry.pack()

    credits_note_label = tk.Label(root, text="Now input your WASSCE Scores in the following subjects(A, B, C, D, E or F)\n\n")
    credits_note_label.pack()
    math_label = tk.Label(root, text="Math:")
    math_label.pack()
    math_entry = tk.Entry(root)
    math_entry.pack()

    eng_label = tk.Label(root, text="English:")
    eng_label.pack()
    eng_entry = tk.Entry(root)
    eng_entry.pack()

    chem_label = tk.Label(root, text="Chemistry:")
    chem_label.pack()
    chem_entry = tk.Entry(root)
    chem_entry.pack()

    phy_label = tk.Label(root, text="Physics:")
    phy_label.pack()
    phy_entry = tk.Entry(root)
    phy_entry.pack()

    civ_label = tk.Label(root, text="Civics Education")
    civ_label.pack()
    civ_entry = tk.Entry(root)
    civ_entry.pack()

    submit_button = tk.Button(root, text="Submit", command=submit)
    submit_button.pack()

root = tk.Tk()
root.title("Pan Atlantic University Admission")
root.geometry("500x250")

# Ask for Department
dept_label = tk.Label(root, text="What's your department(Pick with number)\n\n1) Computer Science\n2) Mass Communication")
dept_label.pack()
dept_entry = tk.Entry(root)
dept_entry.pack()

submit1_button = tk.Button(root, text="Submit", command=submit1)
submit1_button.pack()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 199
#     196 submit1_button = tk.Button(root, text="Submit", command=submit1)
#     197 submit1_button.pack()
# --> 199 root.mainloop()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\tkinter\__init__.py:1504, in Misc.mainloop(self, n)
#    1502 def mainloop(self, n=0):
#    1503     """Call the mainloop of Tk."""
# -> 1504     self.tk.mainloop(n)
#
# KeyboardInterrupt:
